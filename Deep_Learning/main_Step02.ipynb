# %% [markdown]
# # **SpectraNet** <span style="font-size:60%;">: 수어 인식을 위한 Multi-Stream EfficientNetV2 경량화 버전</span>

# %%
import os
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
import pickle
import importlib

from utils.data_loader import AugmentedRadarDataset, get_class_weights
from train.train_model import train_model
from utils.plot_save import plot_training_curve, plot_confusion_matrix, save_metrics
# Out:
# 2025-09-23 22:44:51.337905: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-23 22:44:51.362119: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-23 22:44:51.748101: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# <GPU Memory>
# GPU 설정: 메모리 동적 할당
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU 메모리 할당이 동적으로 설정되었습니다.")
    except RuntimeError as e:
        print(f"GPU 메모리 설정 중 오류 발생: {e}")
# Out:
# GPU 메모리 할당이 동적으로 설정되었습니다.
# 2025-09-23 22:44:52.764996: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.793408: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.793686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# 실험 경로 및 데이터셋 설정
experiment_root = "experiments/Step_02"
DATASET_DIR = "dataset/preprocessed"
os.makedirs(experiment_root, exist_ok=True)
label_csv_path = os.path.join(DATASET_DIR, "labels.csv")
split_file_path = os.path.join("splits.pkl")

n_classes = 15
batch_size = 32
EPOCHS = 50
LEARNING_RATE = 1e-3
apply_class_weights = False

model_list = ["spectranet_v3"]

input_shapes = {
    'rtm_input': (224,224,3),
    'dtm_input': (224,224,3)
}

class_names = [
    "hello", 
    "nice to meet you", 
    "thank you", 
    "i respect you", 
    "sign language", 
    "i love you", 
    "take care", 
    "i'm sorry",
    "be happy",
    "welcome", 
    "enjoy your meal", 
    "aha, i see",
    "i understand",
    "goodbye",
    "no gesture"
]

# %%
# === 데이터 준비 ===
df = pd.read_csv(label_csv_path)
df['base_id'] = df['file'].apply(lambda x: x.rsplit('_', 1)[0])
base_df = df.drop_duplicates('base_id')

# label + subject 조합 생성
base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# stratify용 map (label+subject)
label_subject_map = dict(zip(base_df['base_id'], base_df['label_subject']))

# 학습용 label map (int)
label_map = dict(zip(base_df['base_id'], base_df['label']))
# Out:
# /tmp/ipykernel_67940/881225751.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
# /tmp/ipykernel_67940/881225751.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# %%
if not os.path.exists(split_file_path):
    base_ids = base_df['base_id'].tolist()
    stratify_label_subject = [label_subject_map[bid] for bid in base_ids]

    train_base, val_base = train_test_split(
        base_ids, test_size=0.1, stratify=stratify_label_subject, random_state=18)

    split_dict = {'train': train_base, 'val': val_base}
    with open(split_file_path, 'wb') as f:
        pickle.dump(split_dict, f)
    print("[Info] base_id 단위 stratified split (label + subject) -> splits.pkl 저장 완료")
else:
    with open(split_file_path, 'rb') as f:
        split_dict = pickle.load(f)
    train_base, val_base = split_dict['train'], split_dict['val']
    print("[Info] splits.pkl 로드 완료")
# Out:
# [Info] splits.pkl 로드 완료

# %%
# 증강
def augment_rtm_dtm(rtm, dtm, max_shift=25, stretch_range=(0.5, 1.5)):

    rtm.set_shape([224, 224, 3])
    dtm.set_shape([224, 224, 3])
    
    # === RTM: 채널 동기화 수직 이동 ===
    shift = tf.random.uniform([], minval=-max_shift, maxval=max_shift + 1, dtype=tf.int32)

    def rtm_shift_fn(img):
        if_shift = tf.cond(
            shift > 0,
            lambda: tf.concat([tf.zeros([shift, 224, 3]), img[:-shift, :, :]], axis=0),
            lambda: tf.concat([img[-shift:, :, :], tf.zeros([-shift, 224, 3])], axis=0),
        )
        return if_shift

    rtm = rtm_shift_fn(rtm)

    # === DTM: 채널 동기화된 위/아래 stretch ===
    scale = tf.random.uniform([], stretch_range[0], stretch_range[1])

    mid = tf.shape(dtm)[0] // 2
    top = dtm[:mid, :, :]
    bottom = dtm[mid:, :, :]

    new_top = tf.image.resize(top, (tf.cast(tf.cast(mid, tf.float32) * scale, tf.int32), 224), method="bilinear")
    new_bottom = tf.image.resize(bottom, (tf.cast(tf.cast(224 - mid, tf.float32) * scale, tf.int32), 224), method="bilinear")

    dtm = tf.concat([new_top, new_bottom], axis=0)
    dtm = tf.image.resize_with_crop_or_pad(dtm, 224, 224)

    return rtm, dtm

# %%
sample_ids = np.random.choice(train_base, size=5, replace=False)

for i, sid in enumerate(sample_ids):
    # 원본 데이터 로딩
    rtm = np.load(os.path.join(DATASET_DIR, f"{sid}_rtm.npy")).astype(np.float32)
    dtm = np.load(os.path.join(DATASET_DIR, f"{sid}_dtm.npy")).astype(np.float32)

    # Tensor로 변환 후 증강 적용
    rtm_tf = tf.convert_to_tensor(rtm)
    dtm_tf = tf.convert_to_tensor(dtm)
    rtm_aug, dtm_aug = augment_rtm_dtm(rtm_tf, dtm_tf)

    # NumPy로 변환
    rtm_aug_np = rtm_aug.numpy()
    dtm_aug_np = dtm_aug.numpy()

    # 시각화
    fig, axs = plt.subplots(2, 4, figsize=(12, 6))
    axs[0, 0].imshow(rtm[:, :, 0]); axs[0, 0].set_title("RTM original - C0")
    axs[0, 1].imshow(rtm[:, :, 1]); axs[0, 1].set_title("RTM original - C1")
    axs[0, 2].imshow(rtm[:, :, 2]); axs[0, 2].set_title("RTM original - C2")
    axs[0, 3].imshow(rtm_aug_np[:, :, 1]); axs[0, 3].set_title("RTM augmented - C1")

    axs[1, 0].imshow(dtm[:, :, 0]); axs[1, 0].set_title("DTM original - C0")
    axs[1, 1].imshow(dtm[:, :, 1]); axs[1, 1].set_title("DTM original - C1")
    axs[1, 2].imshow(dtm[:, :, 2]); axs[1, 2].set_title("DTM original - C2")
    axs[1, 3].imshow(dtm_aug_np[:, :, 1]); axs[1, 3].set_title("DTM augmented - C1")

    for ax in axs.flat:
        ax.axis('off')
    plt.suptitle(f"Sample {i+1}: base_id = {sid}", fontsize=14)
    plt.tight_layout()
    plt.show()
# Out:
# 2025-09-23 22:44:52.886272: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.886491: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.886715: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.959142: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.959368: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.959375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-09-23 22:44:52.959515: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-09-23 22:44:52.959539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# === split summary ===
print(f"\n[Split Info]")
print(f"Train: {len(train_base)} samples")
print(f"Val:   {len(val_base)} samples")

def print_distribution(base_ids, base_df, name=""):
    subset_df = base_df[base_df['base_id'].isin(base_ids)]

    # 라벨 분포
    label_counts = subset_df['label'].value_counts().sort_index()
    label_df = pd.DataFrame({'count': label_counts})
    print(f"\n{name} 라벨 분포:")
    print(label_df)

    # subject 분포
    subject_counts = subset_df['subject'].value_counts()
    subject_df = pd.DataFrame({'count': subject_counts})
    print(f"\n{name} subject 분포:")
    print(subject_df)

    # 라벨 x subject 조합 pivot table
    pivot = pd.crosstab(subset_df['label'], subset_df['subject'])
    print(f"\n{name} 라벨 vs subject 분포:")
    print(pivot)


print_distribution(train_base, base_df, "Train")
print_distribution(val_base, base_df, "Val")
# Out:
# [Split Info]
# Train: 4860 samples
# Val:   540 samples
#
# Train 라벨 분포:
#        count
# label
# 0        324
# 1        324
# 2        324
# 3        324
# 4        324
# 5        324
# 6        324
# 7        324
# 8        324
# 9        324
# 10       324
# 11       324
# 12       324
# 13       324
# 14       324
#
# Train subject 분포:
#          count
# subject
# N         1620
# D         1620
# G         1620
#
# Train 라벨 vs subject 분포:
# subject    D    G    N
# label
# 0        108  108  108
# 1        108  108  108
# 2        108  108  108
# 3        108  108  108
# 4        108  108  108
# 5        108  108  108
# 6        108  108  108
# 7        108  108  108
# 8        108  108  108
# 9        108  108  108
# 10       108  108  108
# 11       108  108  108
# 12       108  108  108
# 13       108  108  108
# 14       108  108  108
#
# Val 라벨 분포:
#        count
# label
# 0         36
# 1         36
# 2         36
# 3         36
# 4         36
# 5         36
# 6         36
# 7         36
# 8         36
# 9         36
# 10        36
# 11        36
# 12        36
# 13        36
# 14        36
#
# Val subject 분포:
#          count
# subject
# N          180
# D          180
# G          180
#
# Val 라벨 vs subject 분포:
# subject   D   G   N
# label
# 0        12  12  12
# 1        12  12  12
# 2        12  12  12
# 3        12  12  12
# 4        12  12  12
# 5        12  12  12
# 6        12  12  12
# 7        12  12  12
# 8        12  12  12
# 9        12  12  12
# 10       12  12  12
# 11       12  12  12
# 12       12  12  12
# 13       12  12  12
# 14       12  12  12

# %%
# === split summary ===
print(f"\n[Split Info]")
print(f"Train: {len(train_base)} samples")
print(f"Val:   {len(val_base)} samples")

def print_distribution(base_ids, base_df, name=""):
    subset_df = base_df[base_df['base_id'].isin(base_ids)]

    # 라벨 분포
    label_counts = subset_df['label'].value_counts().sort_index()
    label_df = pd.DataFrame({'count': label_counts})
    print(f"\n{name} 라벨 분포:")
    print(label_df)

    # subject 분포
    subject_counts = subset_df['subject'].value_counts()
    subject_df = pd.DataFrame({'count': subject_counts})
    print(f"\n{name} subject 분포:")
    print(subject_df)

    # 라벨 x subject 조합 pivot table
    pivot = pd.crosstab(subset_df['label'], subset_df['subject'])
    print(f"\n{name} 라벨 vs subject 분포:")
    print(pivot)


print_distribution(train_base, base_df, "Train")
print_distribution(val_base, base_df, "Val")
# Out:
# [Split Info]
# Train: 4860 samples
# Val:   540 samples
#
# Train 라벨 분포:
#        count
# label
# 0        324
# 1        324
# 2        324
# 3        324
# 4        324
# 5        324
# 6        324
# 7        324
# 8        324
# 9        324
# 10       324
# 11       324
# 12       324
# 13       324
# 14       324
#
# Train subject 분포:
#          count
# subject
# N         1620
# D         1620
# G         1620
#
# Train 라벨 vs subject 분포:
# subject    D    G    N
# label
# 0        108  108  108
# 1        108  108  108
# 2        108  108  108
# 3        108  108  108
# 4        108  108  108
# 5        108  108  108
# 6        108  108  108
# 7        108  108  108
# 8        108  108  108
# 9        108  108  108
# 10       108  108  108
# 11       108  108  108
# 12       108  108  108
# 13       108  108  108
# 14       108  108  108
#
# Val 라벨 분포:
#        count
# label
# 0         36
# 1         36
# 2         36
# 3         36
# 4         36
# 5         36
# 6         36
# 7         36
# 8         36
# 9         36
# 10        36
# 11        36
# 12        36
# 13        36
# 14        36
#
# Val subject 분포:
#          count
# subject
# N          180
# D          180
# G          180
#
# Val 라벨 vs subject 분포:
# subject   D   G   N
# label
# 0        12  12  12
# 1        12  12  12
# 2        12  12  12
# 3        12  12  12
# 4        12  12  12
# 5        12  12  12
# 6        12  12  12
# 7        12  12  12
# 8        12  12  12
# 9        12  12  12
# 10       12  12  12
# 11       12  12  12
# 12       12  12  12
# 13       12  12  12
# 14       12  12  12

# %%
# === Data Loaders ===
train_data = AugmentedRadarDataset(train_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR, augment_fn=augment_rtm_dtm)
val_data   = AugmentedRadarDataset(val_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR)

train_dataset = train_data.get_dataset()
val_dataset   = val_data.get_dataset()

if apply_class_weights:
    class_weights = get_class_weights(label_map, train_base, n_classes)
else:
    class_weights = None

# %%
for model_name in model_list:
    print(f"\n[실험 시작] {model_name}")
    model_dir = os.path.join(experiment_root, model_name)
    os.makedirs(model_dir, exist_ok=True)

    # 동적으로 모델 빌드 함수 import
    module = importlib.import_module(f"model.{model_name}")
    build_fn = getattr(module, f"build_{model_name}")

    # 모델 생성
    model = build_fn(input_shapes=input_shapes, num_classes=n_classes)
    plot_model(model, to_file=os.path.join(model_dir, "architecture.png"), show_shapes=True, expand_nested=False)

    # 학습
    history = train_model(model, train_dataset, val_dataset,
                          output_dir=model_dir,
                          class_weights=class_weights,
                          epochs=EPOCHS,
                          learning_rate=LEARNING_RATE)
    plot_training_curve(history, model_dir, smooth=True)

    # history 저장
    with open(os.path.join(model_dir, "history.pkl"), 'wb') as f:
        pickle.dump(history.history, f)

    # 평가
    print(f"[평가 시작] {model_name}")
    best_model = load_model(os.path.join(model_dir, "best_model.keras"))
    loss, acc = best_model.evaluate(val_dataset, verbose=1)

    # Confusion Matrix
    y_true, y_pred = [], []
    for batch_x, batch_y in val_dataset:
        preds = best_model.predict(batch_x, verbose=0)
        y_true.extend(batch_y.numpy())
        y_pred.extend(np.argmax(preds, axis=1))

    cm = confusion_matrix(y_true, y_pred)
    save_metrics(acc, loss, model_dir, best_model.count_params(),
                 y_true=y_true, y_pred=y_pred, class_names=class_names)
    plot_confusion_matrix(cm, save_path=model_dir, acc=acc, loss=loss, labels=class_names)

    print(f"[DONE] {model_name}: acc={acc:.4f}, loss={loss:.4f}")
# Out:
# [실험 시작] spectranet_v3
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/50
# 2025-09-23 22:45:11.312693: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inSpectraNet/rtm_stage1_s24_b1_dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-09-23 22:45:14.963815: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-09-23 22:45:15.187567: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-09-23 22:45:15.538404: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa84e622510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-23 22:45:15.538436: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-09-23 22:45:15.541799: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-23 22:45:15.606558: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# [CUSTOM CHECKPOINT] Epoch 1: 새로운 최고 정확도 0.0667 - 모델 저장!
# 152/152 - 46s - loss: 1.9580 - accuracy: 0.3759 - val_loss: 2.9105 - val_accuracy: 0.0667 - lr: 0.0010 - 46s/epoch - 302ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/50
# 152/152 - 24s - loss: 0.6428 - accuracy: 0.8368 - val_loss: 3.7209 - val_accuracy: 0.0667 - lr: 0.0010 - 24s/epoch - 161ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/50
# [CUSTOM CHECKPOINT] Epoch 3: 새로운 최고 정확도 0.0796 - 모델 저장!
# 152/152 - 22s - loss: 0.3181 - accuracy: 0.9239 - val_loss: 3.7878 - val_accuracy: 0.0796 - lr: 0.0010 - 22s/epoch - 146ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/50
# [CUSTOM CHECKPOINT] Epoch 4: 새로운 최고 정확도 0.5870 - 모델 저장!
# 152/152 - 21s - loss: 0.1613 - accuracy: 0.9621 - val_loss: 1.2084 - val_accuracy: 0.5870 - lr: 0.0010 - 21s/epoch - 139ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/50
# [CUSTOM CHECKPOINT] Epoch 5: 새로운 최고 정확도 0.7167 - 모델 저장!
# 152/152 - 21s - loss: 0.1285 - accuracy: 0.9693 - val_loss: 0.9289 - val_accuracy: 0.7167 - lr: 0.0010 - 21s/epoch - 141ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/50
# 152/152 - 21s - loss: 0.1104 - accuracy: 0.9693 - val_loss: 1.4833 - val_accuracy: 0.6722 - lr: 0.0010 - 21s/epoch - 136ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/50
# [CUSTOM CHECKPOINT] Epoch 7: 새로운 최고 정확도 0.9185 - 모델 저장!
# 152/152 - 21s - loss: 0.0648 - accuracy: 0.9850 - val_loss: 0.2311 - val_accuracy: 0.9185 - lr: 0.0010 - 21s/epoch - 138ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/50
# 152/152 - 21s - loss: 0.0682 - accuracy: 0.9831 - val_loss: 0.5866 - val_accuracy: 0.8185 - lr: 0.0010 - 21s/epoch - 137ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/50
# 152/152 - 21s - loss: 0.0736 - accuracy: 0.9800 - val_loss: 1.1853 - val_accuracy: 0.7204 - lr: 0.0010 - 21s/epoch - 137ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/50
# [CUSTOM CHECKPOINT] Epoch 10: 새로운 최고 정확도 0.9352 - 모델 저장!
# 152/152 - 21s - loss: 0.0548 - accuracy: 0.9846 - val_loss: 0.2212 - val_accuracy: 0.9352 - lr: 0.0010 - 21s/epoch - 141ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 11/50
# 152/152 - 21s - loss: 0.0409 - accuracy: 0.9893 - val_loss: 0.2754 - val_accuracy: 0.9111 - lr: 0.0010 - 21s/epoch - 135ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 12/50
# [CUSTOM CHECKPOINT] Epoch 12: 새로운 최고 정확도 0.9500 - 모델 저장!
# 152/152 - 21s - loss: 0.0427 - accuracy: 0.9881 - val_loss: 0.1778 - val_accuracy: 0.9500 - lr: 0.0010 - 21s/epoch - 141ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 13/50
# 152/152 - 21s - loss: 0.0251 - accuracy: 0.9932 - val_loss: 0.4019 - val_accuracy: 0.8685 - lr: 0.0010 - 21s/epoch - 135ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 14/50
# 152/152 - 21s - loss: 0.0593 - accuracy: 0.9802 - val_loss: 0.7488 - val_accuracy: 0.8019 - lr: 0.0010 - 21s/epoch - 135ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 15/50
# [CUSTOM CHECKPOINT] Epoch 15: 새로운 최고 정확도 0.9704 - 모델 저장!
# 152/152 - 22s - loss: 0.0667 - accuracy: 0.9790 - val_loss: 0.1122 - val_accuracy: 0.9704 - lr: 0.0010 - 22s/epoch - 143ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 16/50
# [CUSTOM CHECKPOINT] Epoch 16: 새로운 최고 정확도 0.9852 - 모델 저장!
# 152/152 - 21s - loss: 0.0209 - accuracy: 0.9951 - val_loss: 0.0537 - val_accuracy: 0.9852 - lr: 0.0010 - 21s/epoch - 141ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 17/50
# [CUSTOM CHECKPOINT] Epoch 17: 새로운 최고 정확도 0.9981 - 모델 저장!
# 152/152 - 21s - loss: 0.0146 - accuracy: 0.9967 - val_loss: 0.0138 - val_accuracy: 0.9981 - lr: 0.0010 - 21s/epoch - 141ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 18/50
# 152/152 - 21s - loss: 0.0364 - accuracy: 0.9901 - val_loss: 0.0910 - val_accuracy: 0.9759 - lr: 0.0010 - 21s/epoch - 141ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 19/50
# 152/152 - 21s - loss: 0.0369 - accuracy: 0.9895 - val_loss: 0.9582 - val_accuracy: 0.7926 - lr: 0.0010 - 21s/epoch - 139ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 20/50
# 152/152 - 21s - loss: 0.0253 - accuracy: 0.9934 - val_loss: 0.0197 - val_accuracy: 0.9907 - lr: 0.0010 - 21s/epoch - 137ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 21/50
# 152/152 - 21s - loss: 0.0150 - accuracy: 0.9963 - val_loss: 0.0710 - val_accuracy: 0.9796 - lr: 0.0010 - 21s/epoch - 136ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 22/50
# 152/152 - 21s - loss: 0.0214 - accuracy: 0.9944 - val_loss: 0.2169 - val_accuracy: 0.9500 - lr: 0.0010 - 21s/epoch - 136ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 23/50
# 152/152 - 21s - loss: 0.0183 - accuracy: 0.9949 - val_loss: 0.0399 - val_accuracy: 0.9852 - lr: 0.0010 - 21s/epoch - 136ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 24/50
# 152/152 - 21s - loss: 0.0363 - accuracy: 0.9897 - val_loss: 0.1022 - val_accuracy: 0.9593 - lr: 0.0010 - 21s/epoch - 137ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 25/50
# 152/152 - 21s - loss: 0.0448 - accuracy: 0.9854 - val_loss: 0.1287 - val_accuracy: 0.9611 - lr: 0.0010 - 21s/epoch - 135ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 26/50
# [CUSTOM CHECKPOINT] Epoch 26: 동률 정확도에서 낮은 손실 0.0093 - 모델 저장!
# 152/152 - 21s - loss: 0.0122 - accuracy: 0.9971 - val_loss: 0.0093 - val_accuracy: 0.9981 - lr: 0.0010 - 21s/epoch - 141ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 27/50
# 152/152 - 21s - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.0161 - val_accuracy: 0.9963 - lr: 0.0010 - 21s/epoch - 138ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 28/50
# 152/152 - 21s - loss: 0.0181 - accuracy: 0.9953 - val_loss: 0.0780 - val_accuracy: 0.9667 - lr: 0.0010 - 21s/epoch - 136ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 29/50
# 152/152 - 21s - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.9215 - val_accuracy: 0.8389 - lr: 0.0010 - 21s/epoch - 136ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 30/50
# 152/152 - 21s - loss: 0.0471 - accuracy: 0.9848 - val_loss: 1.6753 - val_accuracy: 0.7407 - lr: 0.0010 - 21s/epoch - 137ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 31/50
# 152/152 - 21s - loss: 0.0306 - accuracy: 0.9893 - val_loss: 0.0698 - val_accuracy: 0.9815 - lr: 0.0010 - 21s/epoch - 137ms/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 32/50
# 152/152 - 21s - loss: 0.0237 - accuracy: 0.9928 - val_loss: 0.0107 - val_accuracy: 0.9981 - lr: 0.0010 - 21s/epoch - 139ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 33/50
# 152/152 - 21s - loss: 0.0101 - accuracy: 0.9981 - val_loss: 0.0061 - val_accuracy: 0.9963 - lr: 0.0010 - 21s/epoch - 136ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 34/50
# [CUSTOM CHECKPOINT] Epoch 34: 동률 정확도에서 낮은 손실 0.0082 - 모델 저장!
# 152/152 - 22s - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0082 - val_accuracy: 0.9981 - lr: 0.0010 - 22s/epoch - 142ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 35/50
# [CUSTOM CHECKPOINT] Epoch 35: 동률 정확도에서 낮은 손실 0.0034 - 모델 저장!
# 152/152 - 21s - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.0034 - val_accuracy: 0.9981 - lr: 0.0010 - 21s/epoch - 140ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 36/50
# [CUSTOM CHECKPOINT] Epoch 36: 동률 정확도에서 낮은 손실 0.0022 - 모델 저장!
# 152/152 - 22s - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0022 - val_accuracy: 0.9981 - lr: 1.0000e-04 - 22s/epoch - 147ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 37/50
# [CUSTOM CHECKPOINT] Epoch 37: 새로운 최고 정확도 1.0000 - 모델 저장!
# 152/152 - 21s - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 21s/epoch - 140ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 38/50
# 152/152 - 20s - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0029 - val_accuracy: 0.9981 - lr: 1.0000e-04 - 20s/epoch - 135ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 39/50
# 152/152 - 20s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0021 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 20s/epoch - 135ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 40/50
# [CUSTOM CHECKPOINT] Epoch 40: 동률 정확도에서 낮은 손실 0.0014 - 모델 저장!
# 152/152 - 22s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 22s/epoch - 142ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 41/50
# [CUSTOM CHECKPOINT] Epoch 41: 동률 정확도에서 낮은 손실 0.0011 - 모델 저장!
# 152/152 - 22s - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 22s/epoch - 142ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 42/50
# [CUSTOM CHECKPOINT] Epoch 42: 동률 정확도에서 낮은 손실 0.0011 - 모델 저장!
# 152/152 - 21s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 21s/epoch - 137ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 43/50
# 152/152 - 21s - loss: 7.7510e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 21s/epoch - 137ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 44/50
# [CUSTOM CHECKPOINT] Epoch 44: 동률 정확도에서 낮은 손실 0.0011 - 모델 저장!
# 152/152 - 21s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 21s/epoch - 138ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 45/50
# 152/152 - 20s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 20s/epoch - 134ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 46/50
# 152/152 - 20s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 20s/epoch - 133ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 47/50
# [CUSTOM CHECKPOINT] Epoch 47: 동률 정확도에서 낮은 손실 0.0009 - 모델 저장!
# 152/152 - 21s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 9.3939e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 21s/epoch - 137ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 48/50
# [CUSTOM CHECKPOINT] Epoch 48: 동률 정확도에서 낮은 손실 0.0003 - 모델 저장!
# 152/152 - 21s - loss: 0.0013 - accuracy: 0.9998 - val_loss: 2.9578e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 21s/epoch - 136ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 49/50
# 152/152 - 20s - loss: 0.0014 - accuracy: 0.9998 - val_loss: 6.6271e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 20s/epoch - 134ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 50/50
# 152/152 - 21s - loss: 6.0646e-04 - accuracy: 1.0000 - val_loss: 5.7797e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 21s/epoch - 136ms/step
# [평가 시작] spectranet_v3
# 17/17 [==============================] - 3s 28ms/step - loss: 2.9588e-04 - accuracy: 1.0000
# [DONE] spectranet_v3: acc=1.0000, loss=0.0003
