# %% [markdown]
# # **Lite-GEffNet** <span style="font-size:60%;">: 제스처 인식을 위한 EfficientNetV2 경량화 버전</span>

# %%
import os
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
import pickle
import importlib

from utils.data_loader import RadarDataset, get_class_weights
from train.train_model import train_model
from utils.plot_save import plot_training_curve, plot_confusion_matrix, save_metrics
# Out:
# 2025-07-14 06:44:30.107481: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-14 06:44:30.131739: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-14 06:44:30.512246: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# <GPU Memory>
# GPU 설정: 메모리 동적 할당
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU 메모리 할당이 동적으로 설정되었습니다.")
    except RuntimeError as e:
        print(f"GPU 메모리 설정 중 오류 발생: {e}")
# Out:
# GPU 메모리 할당이 동적으로 설정되었습니다.
# 2025-07-14 06:44:31.603018: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:31.615777: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:31.616182: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# 실험 경로 및 데이터셋 설정
experiment_root = "experiments/Step_01"
DATASET_DIR = "dataset/preprocessed"
os.makedirs(experiment_root, exist_ok=True)
label_csv_path = os.path.join(DATASET_DIR, "labels.csv")
split_file_path = os.path.join(experiment_root, "splits.pkl")

n_classes = 10
batch_size = 32
EPOCHS = 100
LEARNING_RATE = 1e-3
apply_class_weights = False

model_list = ["multi_effnet"]

input_shapes = {
    'rtm_input': (224,224,3),
    'dtm_input': (224,224,3)
}

class_names = [
    "hello", 
    "nice to meet you", 
    "thank you", 
    "i respect you", 
    "sign language", 
    "i love you", 
    "take care", 
    "i'm sorry",
    "be happy",
    "no gesture"
]

# %%
# === 데이터 준비 ===
df = pd.read_csv(label_csv_path)
df['base_id'] = df['file'].apply(lambda x: x.rsplit('_', 1)[0])
base_df = df.drop_duplicates('base_id')

# label + subject 조합 생성
base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# stratify용 map (label+subject)
label_subject_map = dict(zip(base_df['base_id'], base_df['label_subject']))

# 학습용 label map (int)
label_map = dict(zip(base_df['base_id'], base_df['label']))
# Out:
# /tmp/ipykernel_23075/881225751.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
# /tmp/ipykernel_23075/881225751.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# %%
if not os.path.exists(split_file_path):
    base_ids = base_df['base_id'].tolist()
    stratify_label_subject = [label_subject_map[bid] for bid in base_ids]

    train_base, val_base = train_test_split(
        base_ids, test_size=0.1, stratify=stratify_label_subject, random_state=19)

    split_dict = {'train': train_base, 'val': val_base}
    with open(split_file_path, 'wb') as f:
        pickle.dump(split_dict, f)
    print("[Info] base_id 단위 stratified split (label + subject) -> splits.pkl 저장 완료")
else:
    with open(split_file_path, 'rb') as f:
        split_dict = pickle.load(f)
    train_base, val_base = split_dict['train'], split_dict['val']
    print("[Info] splits.pkl 로드 완료")
# Out:
# [Info] base_id 단위 stratified split (label + subject) -> splits.pkl 저장 완료

# %%
# === split summary ===
print(f"\n[Split Info]")
print(f"Train: {len(train_base)} samples")
print(f"Val:   {len(val_base)} samples")

def print_distribution(base_ids, base_df, name=""):
    subset_df = base_df[base_df['base_id'].isin(base_ids)]

    # 라벨 분포
    label_counts = subset_df['label'].value_counts().sort_index()
    label_df = pd.DataFrame({'count': label_counts})
    print(f"\n{name} 라벨 분포:")
    print(label_df)

    # subject 분포
    subject_counts = subset_df['subject'].value_counts()
    subject_df = pd.DataFrame({'count': subject_counts})
    print(f"\n{name} subject 분포:")
    print(subject_df)

    # 라벨 x subject 조합 pivot table
    pivot = pd.crosstab(subset_df['label'], subset_df['subject'])
    print(f"\n{name} 라벨 vs subject 분포:")
    print(pivot)


print_distribution(train_base, base_df, "Train")
print_distribution(val_base, base_df, "Val")
# Out:
# [Split Info]
# Train: 3240 samples
# Val:   360 samples
#
# Train 라벨 분포:
#        count
# label
# 0        324
# 1        324
# 2        324
# 3        324
# 4        324
# 5        324
# 6        324
# 7        324
# 8        324
# 9        324
#
# Train subject 분포:
#          count
# subject
# N         1080
# D         1080
# G         1080
#
# Train 라벨 vs subject 분포:
# subject    D    G    N
# label
# 0        108  108  108
# 1        108  108  108
# 2        108  108  108
# 3        108  108  108
# 4        108  108  108
# 5        108  108  108
# 6        108  108  108
# 7        108  108  108
# 8        108  108  108
# 9        108  108  108
#
# Val 라벨 분포:
#        count
# label
# 0         36
# 1         36
# 2         36
# 3         36
# 4         36
# 5         36
# 6         36
# 7         36
# 8         36
# 9         36
#
# Val subject 분포:
#          count
# subject
# N          120
# G          120
# D          120
#
# Val 라벨 vs subject 분포:
# subject   D   G   N
# label
# 0        12  12  12
# 1        12  12  12
# 2        12  12  12
# 3        12  12  12
# 4        12  12  12
# 5        12  12  12
# 6        12  12  12
# 7        12  12  12
# 8        12  12  12
# 9        12  12  12

# %%
# === Data Loaders ===
train_data = RadarDataset(train_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR)
val_data   = RadarDataset(val_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR)

train_dataset = train_data.get_dataset()
val_dataset   = val_data.get_dataset()

if apply_class_weights:
    class_weights = get_class_weights(label_map, train_base, n_classes)
else:
    class_weights = None
# Out:
# 2025-07-14 06:44:35.741978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:35.742124: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:35.742218: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:36.024690: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:36.024857: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:36.024867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-14 06:44:36.024993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-14 06:44:36.025024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
for model_name in model_list:
    print(f"\n[실험 시작] {model_name}")
    model_dir = os.path.join(experiment_root, model_name)
    os.makedirs(model_dir, exist_ok=True)

    # 동적으로 모델 빌드 함수 import
    module = importlib.import_module(f"model.{model_name}")
    build_fn = getattr(module, f"build_{model_name}")

    # 모델 생성
    model = build_fn(input_shapes=input_shapes, num_classes=n_classes)
    plot_model(model, to_file=os.path.join(model_dir, "architecture.png"), show_shapes=True, expand_nested=False)

    # 학습
    history = train_model(model, train_dataset, val_dataset,
                          output_dir=model_dir,
                          class_weights=class_weights,
                          epochs=EPOCHS,
                          learning_rate=LEARNING_RATE)
    plot_training_curve(history, model_dir, smooth=True)

    # 평가
    print(f"[평가 시작] {model_name}")
    best_model = load_model(os.path.join(model_dir, "best_model.keras"))
    loss, acc = best_model.evaluate(val_dataset, verbose=1)

    # Confusion Matrix
    y_true, y_pred = [], []
    for batch_x, batch_y in val_dataset:
        preds = best_model.predict(batch_x, verbose=0)
        y_true.extend(batch_y.numpy())
        y_pred.extend(np.argmax(preds, axis=1))

    cm = confusion_matrix(y_true, y_pred)
    save_metrics(acc, loss, model_dir, best_model.count_params(),
                 y_true=y_true, y_pred=y_pred, class_names=class_names)
    plot_confusion_matrix(cm, save_path=model_dir, acc=acc, loss=loss, labels=class_names)

    print(f"[DONE] {model_name}: acc={acc:.4f}, loss={loss:.4f}")
# Out:
# [실험 시작] multi_effnet
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/100
# 2025-07-14 06:44:53.490525: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dtm_backbone/efficientnetv2-b0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-07-14 06:44:58.407566: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-07-14 06:44:58.764186: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-07-14 06:44:59.085571: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55cddfd2f4c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-14 06:44:59.085607: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-14 06:44:59.088979: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-14 06:44:59.152889: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# [CUSTOM CHECKPOINT] Epoch 1: 새로운 최고 정확도 0.3194 - 모델 저장!
# 102/102 - 55s - loss: 2.1507 - accuracy: 0.2182 - val_loss: 1.8561 - val_accuracy: 0.3194 - lr: 0.0010 - 55s/epoch - 537ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/100
# [CUSTOM CHECKPOINT] Epoch 2: 새로운 최고 정확도 0.4639 - 모델 저장!
# 102/102 - 15s - loss: 1.7039 - accuracy: 0.3481 - val_loss: 1.3755 - val_accuracy: 0.4639 - lr: 0.0010 - 15s/epoch - 145ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/100
# [CUSTOM CHECKPOINT] Epoch 3: 새로운 최고 정확도 0.6139 - 모델 저장!
# 102/102 - 14s - loss: 1.2337 - accuracy: 0.5265 - val_loss: 0.9419 - val_accuracy: 0.6139 - lr: 0.0010 - 14s/epoch - 141ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/100
# [CUSTOM CHECKPOINT] Epoch 4: 새로운 최고 정확도 0.8111 - 모델 저장!
# 102/102 - 15s - loss: 0.9120 - accuracy: 0.6741 - val_loss: 0.6217 - val_accuracy: 0.8111 - lr: 0.0010 - 15s/epoch - 145ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/100
# [CUSTOM CHECKPOINT] Epoch 5: 새로운 최고 정확도 0.9167 - 모델 저장!
# 102/102 - 15s - loss: 0.6664 - accuracy: 0.7852 - val_loss: 0.2923 - val_accuracy: 0.9167 - lr: 0.0010 - 15s/epoch - 145ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/100
# 102/102 - 13s - loss: 0.4187 - accuracy: 0.8762 - val_loss: 0.3197 - val_accuracy: 0.8944 - lr: 0.0010 - 13s/epoch - 128ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7
loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.0559 - val_accuracy: 0.9861 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 58/100
# 102/102 - 13s - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0538 - val_accuracy: 0.9861 - lr: 1.0000e-04 - 13s/epoch - 132ms/step
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 59/100
# 102/102 - 13s - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.0486 - val_accuracy: 0.9917 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 60/100
# 102/102 - 13s - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.0511 - val_accuracy: 0.9917 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 61/100
# 102/102 - 13s - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0513 - val_accuracy: 0.9889 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 62/100
# 102/102 - 13s - loss: 0.0047 - accuracy: 0.9994 - val_loss: 0.0570 - val_accuracy: 0.9861 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 63/100
# 102/102 - 13s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9833 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 64/100
# 102/102 - 13s - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0484 - val_accuracy: 0.9889 - lr: 1.0000e-04 - 13s/epoch - 124ms/step
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 65/100
# [CUSTOM CHECKPOINT] Epoch 65: 새로운 최고 정확도 0.9944 - 모델 저장!
# 102/102 - 15s - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0490 - val_accuracy: 0.9944 - lr: 1.0000e-04 - 15s/epoch - 151ms/step
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 66/100
# 102/102 - 13s - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.0473 - val_accuracy: 0.9917 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 67/100
# 102/102 - 13s - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0572 - val_accuracy: 0.9861 - lr: 1.0000e-04 - 13s/epoch - 127ms/step
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 68/100
# 102/102 - 13s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9889 - lr: 1.0000e-04 - 13s/epoch - 125ms/step
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 69/100
# 102/102 - 13s - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0593 - val_accuracy: 0.9889 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 70/100
# 102/102 - 13s - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0581 - val_accuracy: 0.9889 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 71/100
# 102/102 - 13s - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0547 - val_accuracy: 0.9917 - lr: 1.0000e-04 - 13s/epoch - 130ms/step
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 72/100
# 102/102 - 13s - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.0475 - val_accuracy: 0.9917 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 73/100
# 102/102 - 13s - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0503 - val_accuracy: 0.9917 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 74/100
# 102/102 - 13s - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0510 - val_accuracy: 0.9889 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 75/100
# 102/102 - 13s - loss: 0.0064 - accuracy: 0.9994 - val_loss: 0.0534 - val_accuracy: 0.9861 - lr: 1.0000e-04 - 13s/epoch - 127ms/step
#
# Epoch 76: LearningRateScheduler setting learning rate to 1.0000000474974514e-05.
# Epoch 76/100
# 102/102 - 12s - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0495 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 12s/epoch - 122ms/step
#
# Epoch 77: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 77/100
# 102/102 - 13s - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0513 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 126ms/step
#
# Epoch 78: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 78/100
# 102/102 - 14s - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0516 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 14s/epoch - 135ms/step
#
# Epoch 79: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 79/100
# 102/102 - 13s - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.0472 - val_accuracy: 0.9917 - lr: 1.0000e-05 - 13s/epoch - 129ms/step
#
# Epoch 80: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 80/100
# 102/102 - 13s - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0484 - val_accuracy: 0.9917 - lr: 1.0000e-05 - 13s/epoch - 128ms/step
#
# Epoch 81: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 81/100
# 102/102 - 13s - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0560 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 125ms/step
#
# Epoch 82: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 82/100
# [CUSTOM CHECKPOINT] Epoch 82: 동률 정확도에서 낮은 손실 0.0455 - 모델 저장!
# 102/102 - 15s - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.0455 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 15s/epoch - 146ms/step
#
# Epoch 83: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 83/100
# [CUSTOM CHECKPOINT] Epoch 83: 동률 정확도에서 낮은 손실 0.0454 - 모델 저장!
# 102/102 - 15s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0454 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 15s/epoch - 143ms/step
#
# Epoch 84: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 84/100
# 102/102 - 13s - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.0464 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 13s/epoch - 127ms/step
#
# Epoch 85: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 85/100
# 102/102 - 13s - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0491 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 124ms/step
#
# Epoch 86: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 86/100
# 102/102 - 13s - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.0477 - val_accuracy: 0.9917 - lr: 1.0000e-05 - 13s/epoch - 129ms/step
#
# Epoch 87: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 87/100
# 102/102 - 13s - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.0505 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 124ms/step
#
# Epoch 88: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 88/100
# [CUSTOM CHECKPOINT] Epoch 88: 동률 정확도에서 낮은 손실 0.0454 - 모델 저장!
# 102/102 - 14s - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0454 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 14s/epoch - 140ms/step
#
# Epoch 89: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 89/100
# 102/102 - 13s - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0486 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 126ms/step
#
# Epoch 90: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 90/100
# 102/102 - 13s - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0494 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 123ms/step
#
# Epoch 91: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 91/100
# 102/102 - 12s - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0510 - val_accuracy: 0.9861 - lr: 1.0000e-05 - 12s/epoch - 122ms/step
#
# Epoch 92: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 92/100
# 102/102 - 13s - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0469 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 13s/epoch - 124ms/step
#
# Epoch 93: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 93/100
# 102/102 - 13s - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0538 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 123ms/step
#
# Epoch 94: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 94/100
# 102/102 - 13s - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0484 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 124ms/step
#
# Epoch 95: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 95/100
# 102/102 - 13s - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0458 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 13s/epoch - 126ms/step
#
# Epoch 96: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 96/100
# [CUSTOM CHECKPOINT] Epoch 96: 동률 정확도에서 낮은 손실 0.0448 - 모델 저장!
# 102/102 - 15s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 15s/epoch - 144ms/step
#
# Epoch 97: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 97/100
# 102/102 - 13s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0463 - val_accuracy: 0.9944 - lr: 1.0000e-05 - 13s/epoch - 123ms/step
#
# Epoch 98: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 98/100
# 102/102 - 13s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0522 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 123ms/step
#
# Epoch 99: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 99/100
# 102/102 - 13s - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.0494 - val_accuracy: 0.9889 - lr: 1.0000e-05 - 13s/epoch - 128ms/step
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.0000000656873453e-05.
# Epoch 100/100
# 102/102 - 13s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 0.9917 - lr: 1.0000e-05 - 13s/epoch - 124ms/step
# [평가 시작] multi_effnet
# 12/12 [==============================] - 3s 21ms/step - loss: 0.0448 - accuracy: 0.9944
# [DONE] multi_effnet: acc=0.9944, loss=0.0448
