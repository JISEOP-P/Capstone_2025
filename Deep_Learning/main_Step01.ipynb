# %% [markdown]
# # **Lite-GEffNet** <span style="font-size:60%;">: 제스처 인식을 위한 EfficientNetV2 경량화 버전</span>

# %%
import os
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
import pickle
import importlib

from utils.data_loader import RadarDataset, get_class_weights
from train.train_model import train_model
from utils.plot_save import plot_training_curve, plot_confusion_matrix, save_metrics
# Out:
# 2025-07-20 19:55:31.199946: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-20 19:55:31.224340: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-20 19:55:31.664395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# <GPU Memory>
# GPU 설정: 메모리 동적 할당
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU 메모리 할당이 동적으로 설정되었습니다.")
    except RuntimeError as e:
        print(f"GPU 메모리 설정 중 오류 발생: {e}")
# Out:
# GPU 메모리 할당이 동적으로 설정되었습니다.
# 2025-07-20 19:55:32.917340: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:32.935138: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:32.935264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# 실험 경로 및 데이터셋 설정
experiment_root = "experiments/Step_02"
DATASET_DIR = "dataset/preprocessed_02"
os.makedirs(experiment_root, exist_ok=True)
label_csv_path = os.path.join(DATASET_DIR, "labels.csv")
split_file_path = os.path.join(experiment_root, "splits.pkl")

n_classes = 10
batch_size = 32
EPOCHS = 50
LEARNING_RATE = 1e-3
apply_class_weights = False

model_list = ["multi_effnet"]

input_shapes = {
    'rtm_input': (224,224,3),
    'dtm_input': (224,224,3)
}

class_names = [
    "hello", 
    "nice to meet you", 
    "thank you", 
    "i respect you", 
    "sign language", 
    "i love you", 
    "take care", 
    "i'm sorry",
    "be happy",
    "no gesture"
]

# %%
# === 데이터 준비 ===
df = pd.read_csv(label_csv_path)
df['base_id'] = df['file'].apply(lambda x: x.rsplit('_', 1)[0])
base_df = df.drop_duplicates('base_id')

# label + subject 조합 생성
base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# stratify용 map (label+subject)
label_subject_map = dict(zip(base_df['base_id'], base_df['label_subject']))

# 학습용 label map (int)
label_map = dict(zip(base_df['base_id'], base_df['label']))
# Out:
# /tmp/ipykernel_25781/881225751.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
# /tmp/ipykernel_25781/881225751.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# %%
if not os.path.exists(split_file_path):
    base_ids = base_df['base_id'].tolist()
    stratify_label_subject = [label_subject_map[bid] for bid in base_ids]

    train_base, val_base = train_test_split(
        base_ids, test_size=0.1, stratify=stratify_label_subject, random_state=19)

    split_dict = {'train': train_base, 'val': val_base}
    with open(split_file_path, 'wb') as f:
        pickle.dump(split_dict, f)
    print("[Info] base_id 단위 stratified split (label + subject) -> splits.pkl 저장 완료")
else:
    with open(split_file_path, 'rb') as f:
        split_dict = pickle.load(f)
    train_base, val_base = split_dict['train'], split_dict['val']
    print("[Info] splits.pkl 로드 완료")
# Out:
# [Info] base_id 단위 stratified split (label + subject) -> splits.pkl 저장 완료

# %%
# === split summary ===
print(f"\n[Split Info]")
print(f"Train: {len(train_base)} samples")
print(f"Val:   {len(val_base)} samples")

def print_distribution(base_ids, base_df, name=""):
    subset_df = base_df[base_df['base_id'].isin(base_ids)]

    # 라벨 분포
    label_counts = subset_df['label'].value_counts().sort_index()
    label_df = pd.DataFrame({'count': label_counts})
    print(f"\n{name} 라벨 분포:")
    print(label_df)

    # subject 분포
    subject_counts = subset_df['subject'].value_counts()
    subject_df = pd.DataFrame({'count': subject_counts})
    print(f"\n{name} subject 분포:")
    print(subject_df)

    # 라벨 x subject 조합 pivot table
    pivot = pd.crosstab(subset_df['label'], subset_df['subject'])
    print(f"\n{name} 라벨 vs subject 분포:")
    print(pivot)


print_distribution(train_base, base_df, "Train")
print_distribution(val_base, base_df, "Val")
# Out:
# [Split Info]
# Train: 3240 samples
# Val:   360 samples
#
# Train 라벨 분포:
#        count
# label
# 0        324
# 1        324
# 2        324
# 3        324
# 4        324
# 5        324
# 6        324
# 7        324
# 8        324
# 9        324
#
# Train subject 분포:
#          count
# subject
# D         1080
# N         1080
# G         1080
#
# Train 라벨 vs subject 분포:
# subject    D    G    N
# label
# 0        108  108  108
# 1        108  108  108
# 2        108  108  108
# 3        108  108  108
# 4        108  108  108
# 5        108  108  108
# 6        108  108  108
# 7        108  108  108
# 8        108  108  108
# 9        108  108  108
#
# Val 라벨 분포:
#        count
# label
# 0         36
# 1         36
# 2         36
# 3         36
# 4         36
# 5         36
# 6         36
# 7         36
# 8         36
# 9         36
#
# Val subject 분포:
#          count
# subject
# G          120
# N          120
# D          120
#
# Val 라벨 vs subject 분포:
# subject   D   G   N
# label
# 0        12  12  12
# 1        12  12  12
# 2        12  12  12
# 3        12  12  12
# 4        12  12  12
# 5        12  12  12
# 6        12  12  12
# 7        12  12  12
# 8        12  12  12
# 9        12  12  12

# %%
# === Data Loaders ===
train_data = RadarDataset(train_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR)
val_data   = RadarDataset(val_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR)

train_dataset = train_data.get_dataset()
val_dataset   = val_data.get_dataset()

if apply_class_weights:
    class_weights = get_class_weights(label_map, train_base, n_classes)
else:
    class_weights = None
# Out:
# 2025-07-20 19:55:36.876927: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:36.877109: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:36.877251: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:36.955495: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:36.955667: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:36.955677: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-20 19:55:36.955770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-20 19:55:36.955795: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
for model_name in model_list:
    print(f"\n[실험 시작] {model_name}")
    model_dir = os.path.join(experiment_root, model_name)
    os.makedirs(model_dir, exist_ok=True)

    # 동적으로 모델 빌드 함수 import
    module = importlib.import_module(f"model.{model_name}")
    build_fn = getattr(module, f"build_{model_name}")

    # 모델 생성
    model = build_fn(input_shapes=input_shapes, num_classes=n_classes)
    plot_model(model, to_file=os.path.join(model_dir, "architecture.png"), show_shapes=True, expand_nested=False)

    # 학습
    history = train_model(model, train_dataset, val_dataset,
                          output_dir=model_dir,
                          class_weights=class_weights,
                          epochs=EPOCHS,
                          learning_rate=LEARNING_RATE)
    plot_training_curve(history, model_dir, smooth=True)

    # 평가
    print(f"[평가 시작] {model_name}")
    best_model = load_model(os.path.join(model_dir, "best_model.keras"))
    loss, acc = best_model.evaluate(val_dataset, verbose=1)

    # Confusion Matrix
    y_true, y_pred = [], []
    for batch_x, batch_y in val_dataset:
        preds = best_model.predict(batch_x, verbose=0)
        y_true.extend(batch_y.numpy())
        y_pred.extend(np.argmax(preds, axis=1))

    cm = confusion_matrix(y_true, y_pred)
    save_metrics(acc, loss, model_dir, best_model.count_params(),
                 y_true=y_true, y_pred=y_pred, class_names=class_names)
    plot_confusion_matrix(cm, save_path=model_dir, acc=acc, loss=loss, labels=class_names)

    print(f"[DONE] {model_name}: acc={acc:.4f}, loss={loss:.4f}")
# Out:
# [실험 시작] multi_effnet
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/50
# 2025-07-20 19:55:55.319469: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dtm_backbone/efficientnetv2-b0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-07-20 19:56:00.410460: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-07-20 19:56:00.763130: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-07-20 19:56:01.019211: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fdc38bf0040 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-20 19:56:01.019237: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-20 19:56:01.022745: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-20 19:56:01.087708: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# [CUSTOM CHECKPOINT] Epoch 1: 새로운 최고 정확도 0.2861 - 모델 저장!
# 102/102 - 56s - loss: 2.1961 - accuracy: 0.2000 - val_loss: 1.8020 - val_accuracy: 0.2861 - lr: 0.0010 - 56s/epoch - 548ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/50
# [CUSTOM CHECKPOINT] Epoch 2: 새로운 최고 정확도 0.5806 - 모델 저장!
# 102/102 - 15s - loss: 1.5055 - accuracy: 0.4623 - val_loss: 1.1382 - val_accuracy: 0.5806 - lr: 0.0010 - 15s/epoch - 149ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/50
# [CUSTOM CHECKPOINT] Epoch 3: 새로운 최고 정확도 0.9028 - 모델 저장!
# 102/102 - 15s - loss: 0.8613 - accuracy: 0.7247 - val_loss: 0.3804 - val_accuracy: 0.9028 - lr: 0.0010 - 15s/epoch - 146ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/50
# [CUSTOM CHECKPOINT] Epoch 4: 새로운 최고 정확도 0.9556 - 모델 저장!
# 102/102 - 15s - loss: 0.4991 - accuracy: 0.8543 - val_loss: 0.1677 - val_accuracy: 0.9556 - lr: 0.0010 - 15s/epoch - 143ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/50
# [CUSTOM CHECKPOINT] Epoch 5: 새로운 최고 정확도 0.9583 - 모델 저장!
# 102/102 - 15s - loss: 0.3394 - accuracy: 0.9009 - val_loss: 0.1054 - val_accuracy: 0.9583 - lr: 0.0010 - 15s/epoch - 145ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/50
# [CUSTOM CHECKPOINT] Epoch 6: 새로운 최고 정확도 0.9750 - 모델 저장!
# 102/102 - 15s - loss: 0.2140 - accuracy: 0.9420 - val_loss: 0.0795 - val_accuracy: 0.9750 - lr: 0.0010 - 15s/epoch - 142ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/50
# [CUSTOM CHECKPOINT] Epoch 7: 새로운 최고 정확도 0.9806 - 모델 저장!
# 102/102 - 15s - loss: 0.1651 - accuracy: 0.9580 - val_loss: 0.0413 - val_accuracy: 0.9806 - lr: 0.0010 - 15s/epoch - 146ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/50
# 102/102 - 13s - loss: 0.1250 - accuracy: 0.9679 - val_loss: 0.1959 - val_accuracy: 0.9361 - lr: 0.0010 - 13s/epoch - 127ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/50
# 102/102 - 13s - loss: 0.1210 - accuracy: 0.9673 - val_loss: 0.0544 - val_accuracy: 0.9778 - lr: 0.0010 - 13s/epoch - 123ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/50
# [CUSTOM CHECKPOINT] Epoch 10: 새로운 최고 정확도 0.9917 - 모델 저장!
# 102/102 - 14s - loss: 0.1281 - accuracy: 0.9627 - val_loss: 0.0269 - val_accuracy: 0.9917 - lr: 0.0010 - 14s/epoch - 141ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 11/50
# 102/102 - 13s - loss: 0.1134 - accuracy: 0.9673 - val_loss: 0.0439 - val_accuracy: 0.9889 - lr: 0.0010 - 13s/epoch - 125ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 12/50
# 102/102 - 13s - loss: 0.1033 - accuracy: 0.9725 - val_loss: 0.0469 - val_accuracy: 0.9806 - lr: 0.0010 - 13s/epoch - 128ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 13/50
# [CUSTOM CHECKPOINT] Epoch 13: 새로운 최고 정확도 1.0000 - 모델 저장!
# 102/102 - 15s - loss: 0.0752 - accuracy: 0.9799 - val_loss: 0.0060 - val_accuracy: 1.0000 - lr: 0.0010 - 15s/epoch - 143ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 14/50
# 102/102 - 13s - loss: 0.0567 - accuracy: 0.9864 - val_loss: 0.0222 - val_accuracy: 0.9944 - lr: 0.0010 - 13s/epoch - 124ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 15/50
# [CUSTOM CHECKPOINT] Epoch 15: 동률 정확도에서 낮은 손실 0.0040 - 모델 저장!
# 102/102 - 14s - loss: 0.0589 - accuracy: 0.9827 - val_loss: 0.0040 - val_accuracy: 1.0000 - lr: 0.0010 - 14s/epoch - 142ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 16/50
# 102/102 - 13s - loss: 0.0738 - accuracy: 0.9784 - val_loss: 0.0061 - val_accuracy: 1.0000 - lr: 0.0010 - 13s/epoch - 124ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 17/50
# 102/102 - 13s - loss: 0.0982 - accuracy: 0.9707 - val_loss: 0.0378 - val_accuracy: 0.9889 - lr: 0.0010 - 13s/epoch - 125ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 18/50
# 102/102 - 12s - loss: 0.0567 - accuracy: 0.9809 - val_loss: 0.0199 - val_accuracy: 0.9917 - lr: 0.0010 - 12s/epoch - 121ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 19/50
# 102/102 - 13s - loss: 0.0464 - accuracy: 0.9870 - val_loss: 0.0067 - val_accuracy: 0.9972 - lr: 0.0010 - 13s/epoch - 123ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 20/50
# 102/102 - 13s - loss: 0.0608 - accuracy: 0.9833 - val_loss: 0.0062 - val_accuracy: 1.0000 - lr: 0.0010 - 13s/epoch - 123ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 21/50
# 102/102 - 12s - loss: 0.0419 - accuracy: 0.9892 - val_loss: 0.0214 - val_accuracy: 0.9944 - lr: 0.0010 - 12s/epoch - 122ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 22/50
# [CUSTOM CHECKPOINT] Epoch 22: 동률 정확도에서 낮은 손실 0.0015 - 모델 저장!
# 102/102 - 15s - loss: 0.0325 - accuracy: 0.9910 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 0.0010 - 15s/epoch - 148ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 23/50
# [CUSTOM CHECKPOINT] Epoch 23: 동률 정확도에서 낮은 손실 0.0014 - 모델 저장!
# 102/102 - 15s - loss: 0.0403 - accuracy: 0.9904 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 0.0010 - 15s/epoch - 148ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 24/50
# 102/102 - 13s - loss: 0.0586 - accuracy: 0.9815 - val_loss: 0.0133 - val_accuracy: 0.9944 - lr: 0.0010 - 13s/epoch - 124ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 25/50
# 102/102 - 13s - loss: 0.0769 - accuracy: 0.9747 - val_loss: 0.0491 - val_accuracy: 0.9861 - lr: 0.0010 - 13s/epoch - 125ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 26/50
# [CUSTOM CHECKPOINT] Epoch 26: 동률 정확도에서 낮은 손실 0.0012 - 모델 저장!
# 102/102 - 15s - loss: 0.0379 - accuracy: 0.9898 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 144ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 27/50
# 102/102 - 13s - loss: 0.0252 - accuracy: 0.9923 - val_loss: 0.0047 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 28/50
# 102/102 - 13s - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.0032 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 124ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 29/50
# [CUSTOM CHECKPOINT] Epoch 29: 동률 정확도에서 낮은 손실 0.0010 - 모델 저장!
# 102/102 - 15s - loss: 0.0197 - accuracy: 0.9944 - val_loss: 0.0010 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 143ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 30/50
# [CUSTOM CHECKPOINT] Epoch 30: 동률 정확도에서 낮은 손실 0.0008 - 모델 저장!
# 102/102 - 15s - loss: 0.0103 - accuracy: 0.9981 - val_loss: 7.6606e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 145ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 31/50
# 102/102 - 13s - loss: 0.0071 - accuracy: 0.9981 - val_loss: 9.6933e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 32/50
# 102/102 - 13s - loss: 0.0139 - accuracy: 0.9972 - val_loss: 7.9063e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 33/50
# [CUSTOM CHECKPOINT] Epoch 33: 동률 정확도에서 낮은 손실 0.0006 - 모델 저장!
# 102/102 - 15s - loss: 0.0117 - accuracy: 0.9985 - val_loss: 5.8668e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 148ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 34/50
# 102/102 - 13s - loss: 0.0085 - accuracy: 0.9988 - val_loss: 8.4469e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 35/50
# [CUSTOM CHECKPOINT] Epoch 35: 동률 정확도에서 낮은 손실 0.0005 - 모델 저장!
# 102/102 - 15s - loss: 0.0097 - accuracy: 0.9985 - val_loss: 4.6559e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 145ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 36/50
# 102/102 - 13s - loss: 0.0101 - accuracy: 0.9975 - val_loss: 4.7955e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 124ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 37/50
# [CUSTOM CHECKPOINT] Epoch 37: 동률 정확도에서 낮은 손실 0.0004 - 모델 저장!
# 102/102 - 15s - loss: 0.0097 - accuracy: 0.9975 - val_loss: 4.1257e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 149ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 38/50
# 102/102 - 13s - loss: 0.0092 - accuracy: 0.9985 - val_loss: 6.1086e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 39/50
# 102/102 - 13s - loss: 0.0094 - accuracy: 0.9978 - val_loss: 8.8914e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 125ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 40/50
# 102/102 - 13s - loss: 0.0054 - accuracy: 0.9994 - val_loss: 5.9406e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 124ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 41/50
# 102/102 - 13s - loss: 0.0050 - accuracy: 0.9994 - val_loss: 4.5345e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 124ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 42/50
# 102/102 - 13s - loss: 0.0081 - accuracy: 0.9978 - val_loss: 7.8206e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 125ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 43/50
# 102/102 - 13s - loss: 0.0086 - accuracy: 0.9981 - val_loss: 4.6960e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 124ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 44/50
# [CUSTOM CHECKPOINT] Epoch 44: 동률 정확도에서 낮은 손실 0.0003 - 모델 저장!
# 102/102 - 14s - loss: 0.0075 - accuracy: 0.9988 - val_loss: 3.0800e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 14s/epoch - 141ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 45/50
# [CUSTOM CHECKPOINT] Epoch 45: 동률 정확도에서 낮은 손실 0.0002 - 모델 저장!
# 102/102 - 14s - loss: 0.0073 - accuracy: 0.9994 - val_loss: 2.4621e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 14s/epoch - 140ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 46/50
# 102/102 - 13s - loss: 0.0062 - accuracy: 0.9988 - val_loss: 2.8343e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 125ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 47/50
# 102/102 - 13s - loss: 0.0055 - accuracy: 0.9994 - val_loss: 2.9300e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 125ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 48/50
# 102/102 - 13s - loss: 0.0049 - accuracy: 0.9997 - val_loss: 2.6599e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 49/50
# [CUSTOM CHECKPOINT] Epoch 49: 동률 정확도에서 낮은 손실 0.0002 - 모델 저장!
# 102/102 - 14s - loss: 0.0081 - accuracy: 0.9981 - val_loss: 2.3004e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 14s/epoch - 140ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 50/50
# [CUSTOM CHECKPOINT] Epoch 50: 동률 정확도에서 낮은 손실 0.0002 - 모델 저장!
# 102/102 - 15s - loss: 0.0041 - accuracy: 0.9994 - val_loss: 2.1541e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 142ms/step
# [평가 시작] multi_effnet
# 12/12 [==============================] - 3s 19ms/step - loss: 2.1541e-04 - accuracy: 1.0000
# [DONE] multi_effnet: acc=1.0000, loss=0.0002
