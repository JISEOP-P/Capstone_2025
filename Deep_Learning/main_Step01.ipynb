# %% [markdown]
# # **Lite-GEffNet** <span style="font-size:60%;">: 제스처 인식을 위한 EfficientNetV2 경량화 버전</span>

# %%
import os
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
import pickle
import importlib

from utils.data_loader import RadarDataset, get_class_weights
from train.train_model import train_model
from utils.plot_save import plot_training_curve, plot_confusion_matrix, save_metrics
# Out:
# 2025-07-21 06:02:30.914667: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-21 06:02:30.939474: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-21 06:02:31.422782: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# <GPU Memory>
# GPU 설정: 메모리 동적 할당
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU 메모리 할당이 동적으로 설정되었습니다.")
    except RuntimeError as e:
        print(f"GPU 메모리 설정 중 오류 발생: {e}")
# Out:
# GPU 메모리 할당이 동적으로 설정되었습니다.
# 2025-07-21 06:02:32.380098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:32.397151: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:32.397525: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# 실험 경로 및 데이터셋 설정
experiment_root = "experiments/Step_02"
DATASET_DIR = "dataset/preprocessed_02"
os.makedirs(experiment_root, exist_ok=True)
label_csv_path = os.path.join(DATASET_DIR, "labels.csv")
split_file_path = os.path.join(experiment_root, "splits.pkl")

n_classes = 10
batch_size = 32
EPOCHS = 50
LEARNING_RATE = 1e-3
apply_class_weights = False

model_list = ["multi_effnet"]

input_shapes = {
    'rtm_input': (224,224,3),
    'dtm_input': (224,224,3)
}

class_names = [
    "hello", 
    "nice to meet you", 
    "thank you", 
    "i respect you", 
    "sign language", 
    "i love you", 
    "take care", 
    "i'm sorry",
    "be happy",
    "no gesture"
]

# %%
# === 데이터 준비 ===
df = pd.read_csv(label_csv_path)
df['base_id'] = df['file'].apply(lambda x: x.rsplit('_', 1)[0])
base_df = df.drop_duplicates('base_id')

# label + subject 조합 생성
base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# stratify용 map (label+subject)
label_subject_map = dict(zip(base_df['base_id'], base_df['label_subject']))

# 학습용 label map (int)
label_map = dict(zip(base_df['base_id'], base_df['label']))
# Out:
# /tmp/ipykernel_202436/881225751.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['subject'] = base_df['base_id'].apply(lambda x: x.split('_')[-1])
# /tmp/ipykernel_202436/881225751.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_df['label_subject'] = base_df['label'].astype(str) + "_" + base_df['subject']

# %%
if not os.path.exists(split_file_path):
    base_ids = base_df['base_id'].tolist()
    stratify_label_subject = [label_subject_map[bid] for bid in base_ids]

    train_base, val_base = train_test_split(
        base_ids, test_size=0.1, stratify=stratify_label_subject, random_state=18)

    split_dict = {'train': train_base, 'val': val_base}
    with open(split_file_path, 'wb') as f:
        pickle.dump(split_dict, f)
    print("[Info] base_id 단위 stratified split (label + subject) -> splits.pkl 저장 완료")
else:
    with open(split_file_path, 'rb') as f:
        split_dict = pickle.load(f)
    train_base, val_base = split_dict['train'], split_dict['val']
    print("[Info] splits.pkl 로드 완료")
# Out:
# [Info] base_id 단위 stratified split (label + subject) -> splits.pkl 저장 완료

# %%
# === split summary ===
print(f"\n[Split Info]")
print(f"Train: {len(train_base)} samples")
print(f"Val:   {len(val_base)} samples")

def print_distribution(base_ids, base_df, name=""):
    subset_df = base_df[base_df['base_id'].isin(base_ids)]

    # 라벨 분포
    label_counts = subset_df['label'].value_counts().sort_index()
    label_df = pd.DataFrame({'count': label_counts})
    print(f"\n{name} 라벨 분포:")
    print(label_df)

    # subject 분포
    subject_counts = subset_df['subject'].value_counts()
    subject_df = pd.DataFrame({'count': subject_counts})
    print(f"\n{name} subject 분포:")
    print(subject_df)

    # 라벨 x subject 조합 pivot table
    pivot = pd.crosstab(subset_df['label'], subset_df['subject'])
    print(f"\n{name} 라벨 vs subject 분포:")
    print(pivot)


print_distribution(train_base, base_df, "Train")
print_distribution(val_base, base_df, "Val")
# Out:
# [Split Info]
# Train: 3240 samples
# Val:   360 samples
#
# Train 라벨 분포:
#        count
# label
# 0        324
# 1        324
# 2        324
# 3        324
# 4        324
# 5        324
# 6        324
# 7        324
# 8        324
# 9        324
#
# Train subject 분포:
#          count
# subject
# N         1080
# G         1080
# D         1080
#
# Train 라벨 vs subject 분포:
# subject    D    G    N
# label
# 0        108  108  108
# 1        108  108  108
# 2        108  108  108
# 3        108  108  108
# 4        108  108  108
# 5        108  108  108
# 6        108  108  108
# 7        108  108  108
# 8        108  108  108
# 9        108  108  108
#
# Val 라벨 분포:
#        count
# label
# 0         36
# 1         36
# 2         36
# 3         36
# 4         36
# 5         36
# 6         36
# 7         36
# 8         36
# 9         36
#
# Val subject 분포:
#          count
# subject
# G          120
# N          120
# D          120
#
# Val 라벨 vs subject 분포:
# subject   D   G   N
# label
# 0        12  12  12
# 1        12  12  12
# 2        12  12  12
# 3        12  12  12
# 4        12  12  12
# 5        12  12  12
# 6        12  12  12
# 7        12  12  12
# 8        12  12  12
# 9        12  12  12

# %%
# === Data Loaders ===
train_data = RadarDataset(train_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR)
val_data   = RadarDataset(val_base, label_map, batch_size=batch_size, data_dir=DATASET_DIR)

train_dataset = train_data.get_dataset()
val_dataset   = val_data.get_dataset()

if apply_class_weights:
    class_weights = get_class_weights(label_map, train_base, n_classes)
else:
    class_weights = None
# Out:
# 2025-07-21 06:02:36.713065: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:36.713480: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:36.713750: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:36.774953: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:36.775179: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:36.775190: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-21 06:02:36.775318: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-21 06:02:36.775344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
for model_name in model_list:
    print(f"\n[실험 시작] {model_name}")
    model_dir = os.path.join(experiment_root, model_name)
    os.makedirs(model_dir, exist_ok=True)

    # 동적으로 모델 빌드 함수 import
    module = importlib.import_module(f"model.{model_name}")
    build_fn = getattr(module, f"build_{model_name}")

    # 모델 생성
    model = build_fn(input_shapes=input_shapes, num_classes=n_classes)
    plot_model(model, to_file=os.path.join(model_dir, "architecture.png"), show_shapes=True, expand_nested=False)

    # 학습
    history = train_model(model, train_dataset, val_dataset,
                          output_dir=model_dir,
                          class_weights=class_weights,
                          epochs=EPOCHS,
                          learning_rate=LEARNING_RATE)
    plot_training_curve(history, model_dir, smooth=True)

    # 평가
    print(f"[평가 시작] {model_name}")
    best_model = load_model(os.path.join(model_dir, "best_model.keras"))
    loss, acc = best_model.evaluate(val_dataset, verbose=1)

    # Confusion Matrix
    y_true, y_pred = [], []
    for batch_x, batch_y in val_dataset:
        preds = best_model.predict(batch_x, verbose=0)
        y_true.extend(batch_y.numpy())
        y_pred.extend(np.argmax(preds, axis=1))

    cm = confusion_matrix(y_true, y_pred)
    save_metrics(acc, loss, model_dir, best_model.count_params(),
                 y_true=y_true, y_pred=y_pred, class_names=class_names)
    plot_confusion_matrix(cm, save_path=model_dir, acc=acc, loss=loss, labels=class_names)

    print(f"[DONE] {model_name}: acc={acc:.4f}, loss={loss:.4f}")
# Out:
# [실험 시작] multi_effnet
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/50
# 2025-07-21 06:02:55.184098: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dtm_backbone/efficientnetv2-b0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-07-21 06:03:00.315986: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-07-21 06:03:00.677701: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-07-21 06:03:01.023250: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa878023b70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-21 06:03:01.023287: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-07-21 06:03:01.026578: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-21 06:03:01.097137: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# [CUSTOM CHECKPOINT] Epoch 1: 새로운 최고 정확도 0.3750 - 모델 저장!
# 102/102 - 57s - loss: 2.1700 - accuracy: 0.2099 - val_loss: 1.5506 - val_accuracy: 0.3750 - lr: 0.0010 - 57s/epoch - 556ms/step
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/50
# [CUSTOM CHECKPOINT] Epoch 2: 새로운 최고 정확도 0.7028 - 모델 저장!
# 102/102 - 16s - loss: 1.3412 - accuracy: 0.5176 - val_loss: 0.8444 - val_accuracy: 0.7028 - lr: 0.0010 - 16s/epoch - 153ms/step
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/50
# [CUSTOM CHECKPOINT] Epoch 3: 새로운 최고 정확도 0.8306 - 모델 저장!
# 102/102 - 16s - loss: 0.8054 - accuracy: 0.7321 - val_loss: 0.4487 - val_accuracy: 0.8306 - lr: 0.0010 - 16s/epoch - 157ms/step
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/50
# [CUSTOM CHECKPOINT] Epoch 4: 새로운 최고 정확도 0.9194 - 모델 저장!
# 102/102 - 15s - loss: 0.5392 - accuracy: 0.8306 - val_loss: 0.2173 - val_accuracy: 0.9194 - lr: 0.0010 - 15s/epoch - 149ms/step
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/50
# [CUSTOM CHECKPOINT] Epoch 5: 새로운 최고 정확도 0.9250 - 모델 저장!
# 102/102 - 15s - loss: 0.3286 - accuracy: 0.9062 - val_loss: 0.2432 - val_accuracy: 0.9250 - lr: 0.0010 - 15s/epoch - 144ms/step
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 6/50
# [CUSTOM CHECKPOINT] Epoch 6: 새로운 최고 정확도 0.9500 - 모델 저장!
# 102/102 - 15s - loss: 0.2826 - accuracy: 0.9154 - val_loss: 0.1345 - val_accuracy: 0.9500 - lr: 0.0010 - 15s/epoch - 150ms/step
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 7/50
# [CUSTOM CHECKPOINT] Epoch 7: 새로운 최고 정확도 0.9722 - 모델 저장!
# 102/102 - 15s - loss: 0.1700 - accuracy: 0.9543 - val_loss: 0.0851 - val_accuracy: 0.9722 - lr: 0.0010 - 15s/epoch - 147ms/step
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 8/50
# 102/102 - 13s - loss: 0.1793 - accuracy: 0.9475 - val_loss: 0.1173 - val_accuracy: 0.9639 - lr: 0.0010 - 13s/epoch - 128ms/step
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 9/50
# [CUSTOM CHECKPOINT] Epoch 9: 새로운 최고 정확도 0.9833 - 모델 저장!
# 102/102 - 22s - loss: 0.1608 - accuracy: 0.9512 - val_loss: 0.0577 - val_accuracy: 0.9833 - lr: 0.0010 - 22s/epoch - 219ms/step
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 10/50
# 102/102 - 18s - loss: 0.1110 - accuracy: 0.9710 - val_loss: 0.0569 - val_accuracy: 0.9806 - lr: 0.0010 - 18s/epoch - 174ms/step
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 11/50
# [CUSTOM CHECKPOINT] Epoch 11: 새로운 최고 정확도 0.9917 - 모델 저장!
# 102/102 - 15s - loss: 0.1005 - accuracy: 0.9719 - val_loss: 0.0275 - val_accuracy: 0.9917 - lr: 0.0010 - 15s/epoch - 147ms/step
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 12/50
# [CUSTOM CHECKPOINT] Epoch 12: 동률 정확도에서 낮은 손실 0.0263 - 모델 저장!
# 102/102 - 15s - loss: 0.0950 - accuracy: 0.9753 - val_loss: 0.0263 - val_accuracy: 0.9917 - lr: 0.0010 - 15s/epoch - 145ms/step
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 13/50
# 102/102 - 13s - loss: 0.0592 - accuracy: 0.9840 - val_loss: 0.0708 - val_accuracy: 0.9778 - lr: 0.0010 - 13s/epoch - 127ms/step
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 14/50
# 102/102 - 13s - loss: 0.0363 - accuracy: 0.9907 - val_loss: 0.0340 - val_accuracy: 0.9917 - lr: 0.0010 - 13s/epoch - 125ms/step
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 15/50
# 102/102 - 13s - loss: 0.0866 - accuracy: 0.9753 - val_loss: 0.0291 - val_accuracy: 0.9889 - lr: 0.0010 - 13s/epoch - 126ms/step
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 16/50
# 102/102 - 13s - loss: 0.0995 - accuracy: 0.9741 - val_loss: 0.0474 - val_accuracy: 0.9833 - lr: 0.0010 - 13s/epoch - 127ms/step
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 17/50
# [CUSTOM CHECKPOINT] Epoch 17: 새로운 최고 정확도 0.9944 - 모델 저장!
# 102/102 - 15s - loss: 0.0420 - accuracy: 0.9880 - val_loss: 0.0115 - val_accuracy: 0.9944 - lr: 0.0010 - 15s/epoch - 149ms/step
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 18/50
# 102/102 - 13s - loss: 0.0553 - accuracy: 0.9849 - val_loss: 0.0628 - val_accuracy: 0.9861 - lr: 0.0010 - 13s/epoch - 126ms/step
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 19/50
# 102/102 - 13s - loss: 0.0900 - accuracy: 0.9728 - val_loss: 0.0640 - val_accuracy: 0.9778 - lr: 0.0010 - 13s/epoch - 129ms/step
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 20/50
# 102/102 - 14s - loss: 0.0922 - accuracy: 0.9741 - val_loss: 0.0324 - val_accuracy: 0.9861 - lr: 0.0010 - 14s/epoch - 137ms/step
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 21/50
# 102/102 - 13s - loss: 0.0765 - accuracy: 0.9793 - val_loss: 0.0299 - val_accuracy: 0.9917 - lr: 0.0010 - 13s/epoch - 124ms/step
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 22/50
# 102/102 - 13s - loss: 0.0703 - accuracy: 0.9762 - val_loss: 0.0209 - val_accuracy: 0.9889 - lr: 0.0010 - 13s/epoch - 123ms/step
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 23/50
# 102/102 - 13s - loss: 0.0551 - accuracy: 0.9867 - val_loss: 0.0269 - val_accuracy: 0.9944 - lr: 0.0010 - 13s/epoch - 125ms/step
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 24/50
# 102/102 - 13s - loss: 0.0501 - accuracy: 0.9861 - val_loss: 0.0235 - val_accuracy: 0.9889 - lr: 0.0010 - 13s/epoch - 126ms/step
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 25/50
# [CUSTOM CHECKPOINT] Epoch 25: 새로운 최고 정확도 0.9972 - 모델 저장!
# 102/102 - 15s - loss: 0.0344 - accuracy: 0.9923 - val_loss: 0.0096 - val_accuracy: 0.9972 - lr: 0.0010 - 15s/epoch - 144ms/step
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 26/50
# [CUSTOM CHECKPOINT] Epoch 26: 동률 정확도에서 낮은 손실 0.0086 - 모델 저장!
# 102/102 - 15s - loss: 0.0197 - accuracy: 0.9941 - val_loss: 0.0086 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 15s/epoch - 147ms/step
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 27/50
# 102/102 - 13s - loss: 0.0148 - accuracy: 0.9972 - val_loss: 0.0110 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 127ms/step
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 28/50
# [CUSTOM CHECKPOINT] Epoch 28: 동률 정확도에서 낮은 손실 0.0079 - 모델 저장!
# 102/102 - 15s - loss: 0.0130 - accuracy: 0.9972 - val_loss: 0.0079 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 15s/epoch - 146ms/step
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 29/50
# 102/102 - 13s - loss: 0.0116 - accuracy: 0.9975 - val_loss: 0.0085 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 126ms/step
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 30/50
# [CUSTOM CHECKPOINT] Epoch 30: 동률 정확도에서 낮은 손실 0.0038 - 모델 저장!
# 102/102 - 15s - loss: 0.0102 - accuracy: 0.9972 - val_loss: 0.0038 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 15s/epoch - 149ms/step
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 31/50
# 102/102 - 13s - loss: 0.0075 - accuracy: 0.9991 - val_loss: 0.0049 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 32/50
# 102/102 - 13s - loss: 0.0126 - accuracy: 0.9972 - val_loss: 0.0133 - val_accuracy: 0.9944 - lr: 1.0000e-04 - 13s/epoch - 129ms/step
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 33/50
# 102/102 - 13s - loss: 0.0095 - accuracy: 0.9988 - val_loss: 0.0058 - val_accuracy: 0.9944 - lr: 1.0000e-04 - 13s/epoch - 130ms/step
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 34/50
# 102/102 - 13s - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0073 - val_accuracy: 0.9944 - lr: 1.0000e-04 - 13s/epoch - 130ms/step
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 35/50
# 102/102 - 13s - loss: 0.0088 - accuracy: 0.9988 - val_loss: 0.0051 - val_accuracy: 0.9944 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 36/50
# [CUSTOM CHECKPOINT] Epoch 36: 새로운 최고 정확도 1.0000 - 모델 저장!
# 102/102 - 23s - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0035 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 23s/epoch - 225ms/step
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 37/50
# 102/102 - 13s - loss: 0.0066 - accuracy: 0.9991 - val_loss: 0.0041 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 127ms/step
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 38/50
# 102/102 - 13s - loss: 0.0071 - accuracy: 0.9988 - val_loss: 0.0066 - val_accuracy: 0.9944 - lr: 1.0000e-04 - 13s/epoch - 132ms/step
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 39/50
# [CUSTOM CHECKPOINT] Epoch 39: 동률 정확도에서 낮은 손실 0.0022 - 모델 저장!
# 102/102 - 15s - loss: 0.0097 - accuracy: 0.9981 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 147ms/step
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 40/50
# 102/102 - 13s - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.0024 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 127ms/step
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 41/50
# 102/102 - 13s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 132ms/step
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 42/50
# 102/102 - 14s - loss: 0.0064 - accuracy: 0.9991 - val_loss: 0.0088 - val_accuracy: 0.9944 - lr: 1.0000e-04 - 14s/epoch - 133ms/step
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 43/50
# 102/102 - 13s - loss: 0.0060 - accuracy: 0.9988 - val_loss: 0.0023 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 131ms/step
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 44/50
# 102/102 - 13s - loss: 0.0066 - accuracy: 0.9991 - val_loss: 0.0047 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 129ms/step
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 45/50
# 102/102 - 13s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9972 - lr: 1.0000e-04 - 13s/epoch - 129ms/step
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 46/50
# [CUSTOM CHECKPOINT] Epoch 46: 동률 정확도에서 낮은 손실 0.0014 - 모델 저장!
# 102/102 - 15s - loss: 0.0049 - accuracy: 0.9991 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 148ms/step
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 47/50
# 102/102 - 13s - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 127ms/step
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 48/50
# [CUSTOM CHECKPOINT] Epoch 48: 동률 정확도에서 낮은 손실 0.0008 - 모델 저장!
# 102/102 - 15s - loss: 0.0064 - accuracy: 0.9988 - val_loss: 8.4226e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 145ms/step
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 49/50
# [CUSTOM CHECKPOINT] Epoch 49: 동률 정확도에서 낮은 손실 0.0007 - 모델 저장!
# 102/102 - 15s - loss: 0.0045 - accuracy: 0.9994 - val_loss: 7.1787e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 15s/epoch - 147ms/step
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 50/50
# 102/102 - 13s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 13s/epoch - 128ms/step
# [평가 시작] multi_effnet
# 12/12 [==============================] - 3s 21ms/step - loss: 7.1787e-04 - accuracy: 1.0000
# [DONE] multi_effnet: acc=1.0000, loss=0.0007
